# %% [markdown]
# Multi-fidelity Modeling and Experimental Design (Active Learning)

# %%
# General imports
import numpy as np
np.random.seed(20)
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import colors as mcolors
colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
import sys
import os
sys.path.append('../utilities')
import simulation_utils as sim
import plotting_utils as plotting
sys.path.append('../multi-fidelity-gaussian-process')
import drawing_utils as draw_mfsm
import multi_fidelity_surrogate_model_EI as mfsm
from emukit.multi_fidelity.convert_lists_to_array import convert_x_list_to_array
# Out:
# warning in stationary: failed to import cython module: falling back to numpy
# warning in choleskies: failed to import cython module: falling back to numpy

# %%
version = 'vei1.6'
file_in=f'Ge77_rates_CNP_{version}.csv'
if not os.path.exists(f'out/{version}'):
   os.makedirs(f'out/{version}')
if not os.path.exists(f'in/Ge77_rates_new_samples_{version}.csv'):
   fout = open(f'in/Ge77_rates_new_samples_{version}.csv')
   fout.write("#\n ,Sample,Mode,Radius[cm],Thickness[cm],NPanels,Theta[deg],Length[cm],Ge-77[nevents],Ge-77_CNP,Ge-77_CNP_err")
   fout.close()
   

# Set parameter name/x_labels -> needs to be consistent with data input file
x_labels=['Radius[cm]','Thickness[cm]','NPanels', 'Theta[deg]', 'Length[cm]']
x_labels_out = ['Radius [cm]','Thickness [cm]','NPanels', 'Angle [deg]', 'Length [cm]']
y_label_cnp = 'Ge-77_CNP'
y_err_label_cnp = 'Ge-77_CNP_err'
y_label_sim = 'rGe77[nuc/(kg*yr)]'

# Set parameter boundaries
xmin=[0,0,0,0,0]
xmax=[265,20,360,90,150]

# Set parameter boundaries for aquisition function
xlow=[90,2,4,0,1]
xhigh=[250,15,360,90,150]

# Assign costs
low_fidelity_cost = 1.
high_fidelity_cost = 2000.

# Set a fixed point in space for drawings
x_fixed = [160, 2, 40, 45, 20]
# number of sigma for error band drawing on prediction
factor=1.

# Get LF noise from file
#with open(f'in/{file_in}') as f:
#    first_line = f.readline()
#LF_noise=np.round(float(first_line.split(' +')[0].split('= ')[1]),3)

# Get HF and LF data samples from file

data=pd.read_csv(f'in/{file_in}')
#data=data[[f'Mode', x_labels[0], x_labels[1], x_labels[2], x_labels[3], x_labels[4],y_label_cnp,y_err_label_cnp,y_label_sim]]

LF_noise=np.mean(data.loc[data['Mode']==0.][y_err_label_cnp].to_numpy())
HF_noise=np.mean(data.loc[data['Mode']==1.][y_err_label_cnp].to_numpy())

# %%
#data.plot(kind='scatter', x=x_labels[2], y=x_labels[3], alpha=0.4, s=data[x_labels[4]]*2, label='Ge-77',
#figsize=(12, 8), c=y_label, cmap=plt.get_cmap('jet'), colorbar=True)
#plt.legend()
#plt.show()

# %%
x_train_l, x_train_h, y_train_l, y_train_h = ([],[],[],[])
row_h=data.index[data['Mode'] == 1].tolist()
row_l=data.index[data['Mode'] == 0].tolist()

x_train_hf_sim = data.loc[data['Mode']==1.][x_labels].to_numpy().tolist()
y_train_hf_sim = data.loc[data['Mode']==1.][y_label_sim].to_numpy().tolist()

x_train_hf_cnp = data.loc[data['Mode']==1.][x_labels].to_numpy().tolist()
y_train_hf_cnp = data.loc[data['Mode']==1.][ y_label_cnp].to_numpy().tolist()

x_train_lf_sim = data.loc[data['Mode']==0.][x_labels].to_numpy().tolist()
y_train_lf_sim = data.loc[data['Mode']==0.][ y_label_sim].to_numpy().tolist()

x_train_lf_cnp = data.loc[data['Mode']==0.][x_labels].to_numpy().tolist()
y_train_lf_cnp = data.loc[data['Mode']==0.][ y_label_cnp].to_numpy().tolist()

x_train_lf_cnp, x_train_hf_cnp, x_train_hf_sim, y_train_lf_cnp, y_train_hf_cnp, y_train_hf_sim = (np.atleast_2d(x_train_lf_cnp), np.atleast_2d(x_train_hf_cnp), np.atleast_2d(x_train_hf_cnp), np.atleast_2d(y_train_lf_cnp).T, np.atleast_2d(y_train_hf_cnp).T, np.atleast_2d(y_train_hf_sim).T)

# %%
mf_model = mfsm.linear_multi_fidelity_model(x_train_lf_cnp, y_train_lf_cnp, LF_noise, x_train_hf_cnp, y_train_hf_cnp, HF_noise, x_train_hf_sim, y_train_hf_sim)
# Out:
#  /Users/aschuetz/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/paramz/transformations.py:111: RuntimeWarning:divide by zero encountered in log
# Optimization restart 1/100, f = -288.916416004745
#  /Users/aschuetz/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 2/100, f = -288.9164159928096
# Optimization restart 3/100, f = -288.91641593766116
# Optimization restart 4/100, f = -288.9164160004495
# Optimization restart 5/100, f = -237.04930925414985
# Optimization restart 6/100, f = -288.9164159375071
# Optimization restart 7/100, f = -288.91641601081426
# Optimization restart 8/100, f = -288.91641588198036
# Optimization restart 9/100, f = -288.91641600349544
# Optimization restart 10/100, f = -288.9164160074084
# Optimization restart 11/100, f = -292.4962003106939
# Optimization restart 12/100, f = -288.9164160090158
# Optimization restart 13/100, f = -288.9164160107545
# Optimization restart 14/100, f = -288.9164159982426
# Optimization restart 15/100, f = -292.496200229978
# Optimization restart 16/100, f = -288.91641600835106
# Optimization restart 17/100, f = -288.91641601120983
# Optimization restart 18/100, f = -288.91641601006165
# Optimization restart 19/100, f = -288.9164159746396
# Optimization restart 20/100, f = -292.49620031029576
# Optimization restart 21/100, f = -288.91641601114094
# Optimization restart 22/100, f = -288.91641601089026
# Optimization restart 23/100, f = -288.916415994527
# Optimization restart 24/100, f = -288.91641590285406
# Optimization restart 25/100, f = -288.91641601131664
# Optimization restart 26/100, f = -288.9164159060937
# Optimization restart 27/100, f = -288.9164159978788
# Optimization restart 28/100, f = -288.9164159898247
# Optimization restart 29/100, f = -288.91641600097654
# Optimization restart 30/100, f = -288.9164160046098
# Optimization restart 31/100, f = -288.9164160091074
# Optimization restart 32/100, f = -288.9164160110687
# Optimization restart 33/100, f = -288.9164160109264
# Optimization restart 34/100, f = -288.9164160100151
# Optimization restart 35/100, f = -288.9164160094801
# Optimization restart 36/100, f = -288.9164160060672
# Optimization restart 37/100, f = -288.9164160065299
# Optimization restart 38/100, f = -288.9164160105829
# Optimization restart 39/100, f = -288.91641600818537
# Optimization restart 40/100, f = -288.9164158906501
# Optimization restart 41/100, f = -288.91641593221823
# Optimization restart 42/100, f = -288.91641600844287
# Optimization restart 43/100, f = -288.91641597082486
# Optimization restart 44/100, f = -288.9164157471838
# Optimization restart 45/100, f = -288.91641601102214
# Optimization restart 46/100, f = -288.91641599942045
# Optimization restart 47/100, f = -288.9164160106045
# Optimization restart 48/100, f = -288.9164160046089
# Optimization restart 49/100, f = -288.91641600713444
# Optimization restart 50/100, f = -288.91641601098195
# Optimization restart 51/100, f = -288.91641601064305
# Optimization restart 52/100, f = -288.91641600980876
# Optimization restart 53/100, f = -288.9164178635318
# Optimization restart 54/100, f = -288.9164159710495
# Optimization restart 55/100, f = -288.9164160072664
# Optimization restart 56/100, f = -288.91641600836596
# Optimization restart 57/100, f = -288.9164160104708
#  /Users/aschuetz/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/aschuetz/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 58/100, f = -232.97555015390043
# Optimization restart 59/100, f = -288.91641558434105
# Optimization restart 60/100, f = -288.916416008008
# Optimization restart 61/100, f = -288.91641600913533
# Optimization restart 62/100, f = -288.9164158510289
# Optimization restart 63/100, f = -288.91641601129317
# Optimization restart 64/100, f = -288.91641598394983
# Optimization restart 65/100, f = -288.9164160087813
# Optimization restart 66/100, f = -288.9164160038037
# Optimization restart 67/100, f = -288.91641594951125
# Optimization restart 68/100, f = -288.91641601054687
# Optimization restart 69/100, f = -288.9164160109606
# Optimization restart 70/100, f = -288.9164159699633
# Optimization restart 71/100, f = -292.49620016385325
# Optimization restart 72/100, f = -288.916416002189
# Optimization restart 73/100, f = -288.91641597945323
# Optimization restart 74/100, f = -237.04930910596414
# Optimization restart 75/100, f = -288.9164159980138
# Optimization restart 76/100, f = -288.91641601113156
# Optimization restart 77/100, f = -288.9164160087331
# Optimization restart 78/100, f = -288.91641601061974
# Optimization restart 79/100, f = -288.91641600543153
# Optimization restart 80/100, f = -288.91641593604663
# Optimization restart 81/100, f = -288.9164160089604
# Optimization restart 82/100, f = -288.9164160111263
# Optimization restart 83/100, f = -288.9164160035588
# Optimization restart 84/100, f = -288.9164158513283
# Optimization restart 85/100, f = -288.91641586993046
# Optimization restart 86/100, f = -267.6976011333582
# Optimization restart 87/100, f = -288.9164160086494
# Optimization restart 88/100, f = -232.91413508921883
# Optimization restart 89/100, f = -288.91641593472576
# Optimization restart 90/100, f = -288.91641597856653
# Optimization restart 91/100, f = -288.91641601115526
# Optimization restart 92/100, f = -288.91641544494854
# Optimization restart 93/100, f = -288.9164160106566
# Optimization restart 94/100, f = -288.91641598325697
# Optimization restart 95/100, f = -288.91641599146095
# Optimization restart 96/100, f = -288.9164159001866
# Optimization restart 97/100, f = -288.91641601007336
# Optimization restart 98/100, f = -288.91641600641947
# Optimization restart 99/100, f = -288.9164159416623
# Optimization restart 100/100, f = -237.04930924797844

# %%
# %%capture
leg_label = []
ncol=1
nrow=int(np.ceil(len(x_labels)/ncol))
fig1,ax1  = plt.subplots(2,3, figsize=(15, 5),layout="constrained")
fig2,ax2  = plt.subplots(nrow,ncol, figsize=(5, 12),layout="constrained")

# %%
add_new_sample=True
sample=0
total_samples=20

# %%
while ( sample < total_samples and sample <= max(mfsm.get_num_new_samples(version)[0],mfsm.get_num_new_samples(version)[1])+1 ):
    print('Sample #', sample)
    # add new data point to training data and update model with new training data
    x_new_data=np.array([])
    y_new_data_h=np.array([])
    if sample > 0:
        x_train_lf_cnp, y_train_lf_cnp, x_train_hf_cnp, y_train_hf_cnp, x_train_hf_sim, y_train_hf_sim, mf_model = mfsm.add_samples(x_train_lf_cnp, y_train_lf_cnp, x_train_hf_cnp, y_train_hf_cnp, x_train_hf_sim, y_train_hf_sim, mf_model, x_labels, [y_label_cnp, y_label_sim] ,sample-1, version)

    # run the model drawing
    draw_mfsm.draw_model(mf_model, xmin, xmax, x_labels_out, factor, version)#
    fig1 = draw_mfsm.draw_model_updated(fig1, mf_model, xmin, xmax, x_labels_out, factor, version, x_fixed=x_fixed)
    fig1.show()
    fig1.savefig("update.png")

    # find the next data point
    x_next_sample, us_acquisition = mfsm.max_acquisition_expected_improvement(mf_model, xlow, xhigh, x_labels)
    #x_next_sample, us_acquisition = mfsm.max_acquisition_integrated_variance_reduction(mf_model, xlow, xhigh, x_labels)
    print(f'next suggested point to simulated is at: {x_next_sample}')
    sim.print_geant4_macro(x_next_sample[0],f"n{sample}",mode="LF",version=version)
    sim.print_geant4_macro(x_next_sample[0],f"n{sample}",mode="HF",version=version)
    plotting.draw_moderator_config(x_next_sample[0][0],x_next_sample[0][1],x_next_sample[0][2],x_next_sample[0][3],x_next_sample[0][4])
    fig2 = draw_mfsm.draw_acquisition_func(fig2, us_acquisition, xlow, xhigh, x_labels_out, np.array(x_next_sample), version, x_fixed=x_fixed)
    xi =x_next_sample[0,:-1]

    sample+=1
# Out:
# Sample # 0
#  /var/folders/99/0svbmlns6xs9l9p55lcr912r0000gn/T/ipykernel_73472/2582383103.py:12: UserWarning:Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: too many axes: 2 (effrank=2), expected rank=1
#
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 16
#      13 fig1.savefig("update.png")
#      15 # find the next data point
# ---> 16 x_next_sample, us_acquisition = mfsm.max_acquisition_expected_improvement(mf_model, xlow, xhigh, x_labels)
#      17 #x_next_sample, us_acquisition = mfsm.max_acquisition_integrated_variance_reduction(mf_model, xlow, xhigh, x_labels)
#      18 print(f'next suggested point to simulated is at: {x_next_sample}')
#
# File ~/Documents/Analysis/legend/ML/legend-multi-fidelity-surrogate-model/baseline_models_comparison/multi_fidelity_surrogate_model_EI.py:248, in max_acquisition_expected_improvement(mf_model, xlow, xhigh, labels)
#     246 sequential_point_calculator = SequentialPointCalculator(acquisition, multi_source_acquisition_optimizer)
#     247 loop_state = create_loop_state(mf_model.X, mf_model.Y)
# --> 248 x_next = sequential_point_calculator.compute_next_points(loop_state)
#     250 return x_next, acquisition
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/emukit/core/loop/candidate_point_calculators.py:52, in SequentialPointCalculator.compute_next_points(self, loop_state, context)
#      43 """
#      44 Computes point(s) to evaluate next
#      45
#    (...)
#      49 :return: List of function inputs to evaluate the function at next
#      50 """
#      51 self.acquisition.update_parameters()
# ---> 52 x, _ = self.acquisition_optimizer.optimize(self.acquisition, context)
#      53 return x
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/emukit/core/optimization/multi_source_acquisition_optimizer.py:75, in MultiSourceAcquisitionOptimizer.optimize(self, acquisition, context)
#      71 for i in range(len(self.source_parameter.domain)):
#      72     # Fix the source using a dictionary, the key is the name of the parameter to fix and the value is the
#      73     # value to which the parameter is fixed
#      74     context[self.source_parameter.name] = self.source_parameter.domain[i]
# ---> 75     x, f_maxs[i] = self.acquisition_optimizer.optimize(acquisition, context)
#      76     x_opts.append(x)
#      77 best_source = np.argmax(f_maxs)
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/emukit/core/optimization/acquisition_optimizer.py:48, in AcquisitionOptimizerBase.optimize(self, acquisition, context)
#      46     context = dict()
#      47 context_manager = ContextManager(self.space, context)
# ---> 48 max_x, max_value = self._optimize(acquisition, context_manager)
#      50 # Optimization might not match any encoding exactly
#      51 # Rounding operation here finds the closest encoding
#      52 rounded_max_x = self.space.round(max_x)
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/emukit/core/optimization/gradient_acquisition_optimizer.py:68, in GradientAcquisitionOptimizer._optimize(self, acquisition, context_manager)
#      66 optimized_points = []
#      67 for a in anchor_points:
# ---> 68     optimized_point = apply_optimizer(
#      69         optimizer, a, space=self.space, f=f, df=None, f_df=f_df, context_manager=context_manager
#      70     )
#      71     optimized_points.append(optimized_point)
#      73 x_min, fx_min = min(optimized_points, key=lambda t: t[1])
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/emukit/core/optimization/optimizer.py:130, in apply_optimizer(optimizer, x0, space, f, df, f_df, context_manager)
#     127 else:
#     128     f_df_no_context = problem.f_df_no_context
# --> 130 optimized_x, _ = optimizer.optimize(problem.x0_no_context, f_no_context, df_no_context, f_df_no_context)
#     132 # Add context and round according to the type of variables of the design space
#     133 suggested_x_with_context = add_context(optimized_x)
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/emukit/core/optimization/optimizer.py:70, in OptLbfgs.optimize(self, x0, f, df, f_df)
#      66     res = scipy.optimize.fmin_l_bfgs_b(
#      67         f, x0=x0, bounds=self.bounds, approx_grad=True, maxiter=self.max_iterations
#      68     )
#      69 else:
# ---> 70     res = scipy.optimize.fmin_l_bfgs_b(_f_df, x0=x0, bounds=self.bounds, maxiter=self.max_iterations)
#      72 # We check here if the the optimizer moved. It it didn't we report x0 and f(x0) as scipy can return NaNs
#      73 if res[2]["task"] == b"ABNORMAL_TERMINATION_IN_LNSRCH":
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/scipy/optimize/lbfgsb.py:197, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     185     disp = iprint
#     186 opts = {'disp': disp,
#     187         'iprint': iprint,
#     188         'maxcor': m,
#    (...)
#     194         'callback': callback,
#     195         'maxls': maxls}
# --> 197 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                        **opts)
#     199 d = {'grad': res['jac'],
#     200      'task': res['message'],
#     201      'funcalls': res['nfev'],
#     202      'nit': res['nit'],
#     203      'warnflag': res['status']}
#     204 f = res['fun']
#
# File ~/.local/modules/miniconda/miniconda3/envs/legend/lib/python3.10/site-packages/scipy/optimize/lbfgsb.py:351, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     347 n_iterations = 0
#     349 while 1:
#     350     # x, f, g, wa, iwa, task, csave, lsave, isave, dsave = \
# --> 351     _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr,
#     352                    pgtol, wa, iwa, task, iprint, csave, lsave,
#     353                    isave, dsave, maxls)
#     354     task_str = task.tobytes()
#     355     if task_str.startswith(b'FG'):
#     356         # The minimization routine wants f and g at the current x.
#     357         # Note that interruptions due to maxfun are postponed
#     358         # until the completion of the current minimization iteration.
#     359         # Overwrite f and g:
#
# ValueError: failed in converting 7th argument `g' of _lbfgsb.setulb to C/Fortran array

# %%
draw_mfsm.draw_model_acquisition_func(fig1,fig2,x_labels,version)

# %%
def model_validation(mf_model, file_in, x_labels, y_label, version):
        data=pd.read_csv(file_in)
        #data=data[[f'Mode', x_labels[0], x_labels[1], x_labels[2], x_labels[3], x_labels[4],y_label]]

        x_train_hf_sim = data.loc[data['Mode']==1.][x_labels].to_numpy().tolist()
        y_train_hf_sim = data.loc[data['Mode']==1.][y_label].to_numpy().tolist()
        x_train_hf_sim, y_train_hf_sim = (np.atleast_2d(x_train_hf_sim), np.atleast_2d(y_train_hf_sim).T)

        counter_1sigma = 0
        counter_2sigma = 0
        counter_3sigma = 0

        mfsm_model_mean = np.empty(shape=[0, 0])
        mfsm_model_std = np.empty(shape=[0, 0])
        hf_data=[]
        x=[]
        for i in range(len(x_train_hf_sim)):

                SPLIT = 1
                x_plot = (np.atleast_2d(x_train_hf_sim[i]))
                X_plot = convert_x_list_to_array([x_plot , x_plot, x_plot])
                hhf_mean_mf_model, hhf_var_mf_model = mf_model.predict(X_plot[2*SPLIT:])
                hhf_std_mf_model = np.sqrt(hhf_var_mf_model)

                hf_data.append(y_train_hf_sim[i])
                x.append(i)
                mfsm_model_mean=np.append(mfsm_model_mean,hhf_mean_mf_model[0,0])
                mfsm_model_std=np.append(mfsm_model_std,hhf_std_mf_model[0,0])
                if (y_train_hf_sim[i] < hhf_mean_mf_model+hhf_std_mf_model) and (y_train_hf_sim[i] > hhf_mean_mf_model-hhf_std_mf_model):
                        counter_1sigma += 1
                if (y_train_hf_sim[i] < hhf_mean_mf_model+2*hhf_std_mf_model) and (y_train_hf_sim[i] > hhf_mean_mf_model-2*hhf_std_mf_model):
                        counter_2sigma += 1
                if (y_train_hf_sim[i] < hhf_mean_mf_model+3*hhf_std_mf_model) and (y_train_hf_sim[i] > hhf_mean_mf_model-3*hhf_std_mf_model):
                        counter_3sigma += 1

        print("1 sigma: ", counter_1sigma/len(hf_data)*100.," %" )
        print("2 sigma: ", counter_2sigma/len(hf_data)*100.," %" )
        print("3 sigma: ", counter_3sigma/len(hf_data)*100.," %" )

        fig = plt.subplots(figsize=(12, 2.5))
        #plt.bar(x=np.arange(len(mfsm_model_mean)), height=mfsm_model_mean, color="lightgray", label='RESuM')
        plt.fill_between(x=np.arange(len(mfsm_model_mean)), y1=mfsm_model_mean-3*mfsm_model_std, y2=mfsm_model_mean+3*mfsm_model_std, color="coral",alpha=0.2, label=r'$\pm 3\sigma$')
        plt.fill_between(x=np.arange(len(mfsm_model_mean)), y1=mfsm_model_mean-2*mfsm_model_std, y2=mfsm_model_mean+2*mfsm_model_std, color="yellow",alpha=0.2, label=r'$\pm 2\sigma$')
        plt.fill_between(x=np.arange(len(mfsm_model_mean)), y1=mfsm_model_mean-mfsm_model_std, y2=mfsm_model_mean+mfsm_model_std, color="green",alpha=0.2, label=r'RESuM $\pm 1\sigma$')
        plt.xlabel('HF Simulation Trial Number')
        plt.ylim(0.,0.55)
        plt.ylabel(r'$y_{raw}$')
        plt.plot(x[:],hf_data[:],'.',color="black", label="HF Validation Data")
        handles, labels = plt.gca().get_legend_handles_labels()
        order = [3,2,1,0]
        plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc=9, bbox_to_anchor=(0.665,1.),ncol=5)
        plt.savefig(f'out/{version}/model-validation_{version}.pdf')
        return fig

# %%
while ( sample < total_samples and sample <= max(mfsm.get_num_new_samples(version)[0],mfsm.get_num_new_samples(version)[1])+1 ):
    print('Sample #', sample)
    # add new data point to training data and update model with new training data
    x_new_data=np.array([])
    y_new_data_h=np.array([])
    if sample > 0:
        x_train_lf_cnp, y_train_lf_cnp, x_train_hf_cnp, y_train_hf_cnp, x_train_hf_sim, y_train_hf_sim, mf_model = mfsm.add_samples(x_train_lf_cnp, y_train_lf_cnp, x_train_hf_cnp, y_train_hf_cnp, x_train_hf_sim, y_train_hf_sim, mf_model, x_labels, [y_label_cnp, y_label_sim] ,sample-1, version)

    # run the model drawing
    draw_mfsm.draw_model(mf_model, xmin, xmax, x_labels_out, factor, version)#
    fig1 = draw_mfsm.draw_model_updated(fig1, mf_model, xmin, xmax, x_labels_out, factor, version, x_fixed=x_fixed)
    fig1.show()
    fig1.savefig("update.png")

    # find the next data point
    x_next_sample, us_acquisition = mfsm.max_acquisition_integrated_variance_reduction(mf_model, xlow, xhigh, x_labels)
    print(f'next suggested point to simulated is at: {x_next_sample}')
    sim.print_geant4_macro(x_next_sample[0],f"n{sample}",mode="LF",version=version)
    sim.print_geant4_macro(x_next_sample[0],f"n{sample}",mode="HF",version=version)
    plotting.draw_moderator_config(x_next_sample[0][0],x_next_sample[0][1],x_next_sample[0][2],x_next_sample[0][3],x_next_sample[0][4])
    fig2 = draw_mfsm.draw_acquisition_func(fig2, us_acquisition, xlow, xhigh, x_labels_out, np.array(x_next_sample), version, x_fixed=x_fixed)
    xi =x_next_sample[0,:-1]

    sample+=1

# %%
fig = model_validation(mf_model,"in/hf_validation_data_v1.2.csv",x_labels, y_label_sim, version)
plt.show()

# %%
x_fmin = [150,10,360,0,3]
f_min = 1.
dx_fmin=[]
dy_fmin=[]
dsigma_fmin=[]
for i in range(50):
    x_fmin_tmp, f_min_tmp = mfsm.get_min_constrained(mf_model, xlow, xhigh, x_labels)
    #plotting.draw_moderator_configuration(x_fmin_tmp)
    dx_fmin.append(x_fmin_tmp)
    dy_fmin.append(f_min_tmp)
    dsigma_fmin.append(mfsm.evaluate_model_uncertainty(x_fmin_tmp,mf_model,2))
    print(f"minimum found at {x_fmin_tmp} with f = {f_min_tmp} {mfsm.evaluate_model(x_fmin_tmp,mf_model,2)} +- {mfsm.evaluate_model_uncertainty(x_fmin_tmp,mf_model,2)} and a reduction of {mfsm.evaluate_model([0.,0.,0.,0.,0.],mf_model,2)/f_min_tmp}")

    if f_min_tmp <= f_min:
        x_fmin = x_fmin_tmp
        f_min = f_min_tmp

    itmp=201+i
    sim.print_geant4_macro(x_fmin_tmp,f"{itmp}",mode="LF",version=f"{version}")


print(f"minimum found at {x_fmin} with f = {f_min} and a reduction of {mfsm.evaluate_model([0.,0.,0.,0.,0.], mf_model,2)/f_min}")
print("high fidelity", mfsm.evaluate_model(x_fmin, mf_model,2), mfsm.evaluate_model([x_fmin[0],plotting.get_outer_radius(x_fmin)-plotting.get_inner_radius(x_fmin),360,0.,4.],mf_model,2))
print("medium fidelity", mfsm.evaluate_model(x_fmin, mf_model,1), mfsm.evaluate_model([x_fmin[0],plotting.get_outer_radius(x_fmin)-plotting.get_inner_radius(x_fmin),360,0.,10.],mf_model,1))
plotting.draw_moderator_configuration(x_fmin)
